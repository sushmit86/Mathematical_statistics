# %%
# Examples
import pandas as pd
import numpy as np
from bokeh.charts import Bar,Histogram, output_notebook, show
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# read flights delay data

df_flightsdelay = pd.read_csv('Data/FlightDelays.csv')
df_flightsdelay.head()
# Out:
#    ID Carrier  FlightNo Destination DepartTime  Day Month  FlightLength  \
# 0   1      UA       403         DEN      4-8am  Fri   May           281
# 1   2      UA       405         DEN     8-Noon  Fri   May           277
# 2   3      UA       409         DEN      4-8pm  Fri   May           279
# 3   4      UA       511         ORD     8-Noon  Fri   May           158
# 4   5      UA       667         ORD      4-8am  Fri   May           143
#
#    Delay Delayed30
# 0     -1        No
# 1    102       Yes
# 2      4        No
# 3     -2        No
# 4     -3        No

# %%
df_flightsdelay['Carrier'].value_counts()
# getting box plot
# Out:
# AA    2906
# UA    1123
# Name: Carrier, dtype: int64

# %%
output_notebook()
p = Bar(df_flightsdelay, 'Carrier', title="Bar Chart By Carrier", color = 'wheat', bar_width = 0.4)
show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e9ced31b-a586-4237-9f89-983f980e7202">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="28f67c46-fc45-4c93-be6d-cb99e047903e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("28f67c46-fc45-4c93-be6d-cb99e047903e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '28f67c46-fc45-4c93-be6d-cb99e047903e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ea79da45-9819-49ea-bb2a-0ec09c1a4073":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","line_alpha","fill_alpha","y","line_color","height","color","width"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[1.75],"x":["392.3"],"y":[0.0]}},"id":"a9857932-0665-4eae-907b-a3fc3eb5b110","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","line_alpha","fill_alpha","y","line_color","height","color","width"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"line_alpha":[1.0],"line_color":["black"],"width":[3.549999999999999],"x":["78.15"],"y":[1.5]}},"id":"9a6d693f-e55b-48de-b373-f8cc4d54d719","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7567c745-5743-4a07-8b71-b03933c2cd1a","type":"ColumnDataSource"},"glyph":{"id":"a24f4eb3-1540-42f4-80cf-db5c8f7606ed","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6db44b14-46d3-4470-b493-9dedd550e93a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_alpha","fill_alpha","y","line_color","height","color","width"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[252.0],"line_alpha":[1.0],"line_color":["black"],"width":[253.765],"x":["882.1"],"y":[126.0]}},"id":"2e804d10-7dd1-40cd-a8ed-39d05f575a37","type":"ColumnDataSource"},{"attributes":{},"id":"58cdf132-e27f-43ab-b7e9-b91c5718e871","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"328bfce0-94b1-472e-a399-315f43cde059","type":"ColumnDataSource"},"glyph":{"id":"a4f7bd97-4c9d-41db-9166-6398b10ca402","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"31cf3ef2-681a-49d8-b7da-d9aafa642edf","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"479df7a2-f578-4b0a-b900-3878264c7df6","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","line_alpha","fill_alpha","y","line_color","height","color","width"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[268.0],"line_alpha":[1.0],"line_color":["black"],"width":[1.75],"x":["-7.25"],"y":[134.0]}},"id":"a157bc4c-e98a-4da3-8107-299673b14c93","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1af68177-cf7d-428c-acfc-d1bced39a693","type":"Rect"},{"attributes":{"data_source":{"id":"1ac92fda-4e6a-44d4-a353-7397d37e17d9","type":"ColumnDataSource"},"glyph":{"id":"3434189c-7389-4e76-8ec2-e9f5cd3a88ec","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"934add06-a595-4890-aa52-9dc2561d0f05","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_alpha","fill_alpha","y","line_color","height","color","width"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[3.549999999999999],"x":["195.05"],"y":[0.0]}},"id":"3031bb79-8f0f-4950-9076-29dc4d62eba0","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f9edfa88-f812-4869-b626-c5e7923e44bd","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"fi ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[59]</strong>&gt;</code></p>

# %%
#pd.pivot_table(df_flightsdelay,index= ['Carrier'], columns=['Delayed30'],values=['FlightLength'],
#               aggfunc = len,margins = True)

pd.pivot_table(df_flightsdelay,index= ['Carrier'], columns=['Delayed30'],values=[], aggfunc = len,
               margins = True,margins_name = 'Total')
# Out:
# Delayed30      No    Yes   Total
# Carrier
# AA         2513.0  393.0  2906.0
# UA          919.0  204.0  1123.0
# Total      3432.0  597.0  4029.0

# %%
#df_flightsdelay.groupby(['Carrier','Delayed30']).count()
# Create a histogram for flights delay in tabular format

bins = np.arange(-50,500,50)
df_flightsdelay['Bin_Categories'] = pd.cut(df_flightsdelay['Delay'] , bins)

# %%
hist_series= df_flightsdelay[df_flightsdelay['Carrier'] == 'UA']['Bin_Categories'].value_counts()
print(hist_series)
df_flightsdelay.head()
# Out:
# (-50, 0]      722
# (0, 50]       249
# (50, 100]      86
# (100, 150]     39
# (150, 200]     14
# (200, 250]      7
# (250, 300]      3
# (300, 350]      2
# (350, 400]      1
# (400, 450]      0
# dtype: int64
#    ID Carrier  FlightNo Destination DepartTime  Day Month  FlightLength  \
# 0   1      UA       403         DEN      4-8am  Fri   May           281
# 1   2      UA       405         DEN     8-Noon  Fri   May           277
# 2   3      UA       409         DEN      4-8pm  Fri   May           279
# 3   4      UA       511         ORD     8-Noon  Fri   May           158
# 4   5      UA       667         ORD      4-8am  Fri   May           143
#
#    Delay Delayed30 Bin_Categories
# 0     -1        No       (-50, 0]
# 1    102       Yes     (100, 150]
# 2      4        No        (0, 50]
# 3     -2        No       (-50, 0]
# 4     -3        No       (-50, 0]

# %%
# getting UA
df_flightsdelay.head()
df_flightsdelay.drop(['Bin_Categories'], axis = 1,inplace= True,errors= 'ignore')
df_UA=df_flightsdelay[df_flightsdelay['Carrier']=='UA']

# %%
# plotting using matplotlib
df_UA['Delay'].plot.hist( bins = bins, color = 'navy')

# %%
# Boxplots for distribution of lengths of flights by Day
df_flightsdelay
