# %%
States03 <- read.csv("Data/States03.csv")
head(States03)
barplot(table(States03$Region))
# Out:
#       States Region Population Births Deaths Pop18 Pop65 HSGrad ColGrad
# 1    Alabama  South   4500.752  59797  47209  25.3  13.0   79.9    22.7
# 2     Alaska   West    648.818   9755   3133  30.4   5.7   90.6    24.0
# 3    Arizona   West   5580.811  88154  44124  26.6  13.0   83.8    26.0
# 4   Arkansas  South   2725.714  38292  28486  25.4  14.0   80.9    17.4
# 5 California   West  35484.453 523578 238007  27.3  10.6   81.1    29.8
# 6   Colorado   West   4550.688  67319  30077  25.6   9.7   88.7    36.0
#   TeachersPay InfantMortality TeenBirths ViolentCrime PropertyCrime
# 1       38246             9.4       54.5        444.2        4020.9
# 2       49685             8.1       39.5        563.4        3746.3
# 3       40894             6.9       61.2        552.9        5833.4
# 4       37753             8.3       59.9        424.4        3733.1
# 5       56283             5.4       41.1        593.4        3350.3
# 6       42679             5.8       47.0        352.4        3995.4
#   DeathPenalty Executions Poverty Unemp Uninsured Income Earnings Heart
# 1          Yes         28    16.6  37.7      13.3  35412    13.56 289.3
# 2           No          0     7.7  26.8      17.8  56536    12.16 187.7
# 3          Yes         22    14.2  36.9      17.3  41172    14.38 204.5
# 4          Yes         26    15.3  36.3      16.6  34402    13.55 279.1
# 5          Yes         10    13.0  34.4      18.7  49738    15.05 230.4
# 6          Yes          1     9.7  29.1      16.3  48282    16.89 181.0
#   Vehicles Homeowners
# 1     23.1       76.2
# 2     17.4       70.0
# 3     19.4       67.0
# 4     24.4       69.6
# 5     11.5       58.9
# 6     17.2       71.3
# plot without title

# %%
hist(States03$Poverty)
plot(States03$Unemp, States03$Poverty, xlab = "Unemployment", ylab = "Poverty")
# Out:
# Plot with title “Histogram of States03$Poverty”
# plot without title

# %%
plot(Poverty ~ Unemp, data = States03, xlab = "Unemployment", ylab = "Poverty")
# Out:
# plot without title

# %%
hist(States03$Poverty, main = "Poverty", xlab = "percent",
xlim = c(0, 24), ylim = c(0, 20))
# Out:
# Plot with title “Poverty”

# %%
plot(1:19, 1:19, pch = 1:19, xlab = "x", ylab = "y")
# Out:
# plot without title

# %%
pie(rep(1, 9), col = 1:9)
# Out:
# plot without title

# %%
curve(x^2, from = 0, to = 2)
curve(cos(x), from = 0, to = pi)
curve(cos(x), from = 0, to = pi, lty = 4, col = "red")
# Out:
# plot without title
# plot without title
# plot without title

# %%
plot(Poverty ~ Unemp, data = States03, xlab = "Unemployment", ylab = "Poverty")
abline(v = mean(States03$Unemp), lty = 2) #vertical line at mean unemployment rate,
text(mean(States03$Unemp), 18, "mean unemployment rate") #text at (30, 18)
title("Data from 2003")
# Out:
# Plot with title “Data from 2003”

# %%
range(States03$Poverty)
range(States03$ColGrad)
plot(Poverty ~ ColGrad, data = States03, pch=16, subset =Region=="West", xlim = c(15,40), ylim = c(5, 20))
points(Poverty ~ ColGrad, data = States03, pch=16, col = "red", subset = Region=="South")
points(Poverty ~ ColGrad, data = States03, pch=16, col = "green", subset = Region=="Northeast")
points(Poverty ~ ColGrad, data = States03,pch = 16, col = "blue", subset = Region=="Midwest")
legend("topright", legend=c("West", "South", "Northeast", "Midwest"),
pch = rep(16,4), col = c("black", "red", "green", "blue"))
# Out:
# [1]  6.4 19.9
# [1] 15.3 37.6
# plot without title

# %%
par(mfrow = c(2, 2))
curve(3*x^2)
curve(cos(x))
hist(States03$Population)
qqnorm(States03$Population)
curve(3*x)
qqline(States03$Population)
# Out:
# Plot with title “Normal Q-Q Plot”
# plot without title
